# %% [markdown]
# ## Word2Vec - Large Data

# %%
from __future__ import division, absolute_import, print_function

from six.moves import urllib, xrange

import tensorflow as tf
import numpy as np
import collections, math, os, random, zipfile

# %%
# download the data
url = 'http://mattmahoney.net/dc/'

def download(filename, expected_bytes):

    if not os.path.exists(filename):
        filename, _ = urllib.request.urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

# download the file
file_ = download('text8.zip', 31344016)

def read_data(filename):
    """
    Parse the file enclosed in the 'filename' zip file into a list of words.
    """
    # unzip the file
    with zipfile.ZipFile(filename) as f:
        # read the data into the 'data' variable
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    # return the data
    return data

words = read_data(file_)
print('data size:', len(words))
# Out:
# Found and verified text8.zip
# data size: 17005207

# %%
words[0:10]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against']

# %%
# build the dictionary and replace rare words with the "UNK" token.
vocabulary_size = 50000

def build_dataset(words):
    # create counts list, set counts for "UNK" token to -1 (undefined)
    count = [['UNK', -1]]
    # add counts of the 49,999 most common tokens in 'words'
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    # create the dictionary data structure
    dictionary = {}
    # give a unique integer ID to each token in the dictionary
    for word, _ in count:
        dictionary[word] = len(dictionary)
    # create a list data structure for the data
    data = []
    # keep track of the number of "UNK" token occurrences
    unk_count = 0
    # for each word in our list of words
    for word in words:
        # if its in the dictionary, get its index
        if word in dictionary:
            index = dictionary[word]
        # otherwise, set the index equal to zero (index of "UNK") and increment the "UNK" count
        else:
            index = 0  # dictionary['UNK']
            unk_count += 1
        # append its index to the 'data' list structure
        data.append(index)
    # set the count of "UNK" in the 'count' data structure
    count[0][1] = unk_count
    # invert the dictionary; it becomes (index, word) key-value pairs
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    # return the data (indices), counts, dictionary, and inverted dictionary
    return data, count, dictionary, reverse_dictionary

# build the datset
data, count, dictionary, reverse_dictionary = build_dataset(words)
# free up some memory
del words
# print out stats
print('most common words (+UNK):', count[:10])
print('sample data:', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# most common words (+UNK): [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]
# sample data: [5242, 3083, 12, 6, 195, 2, 3135, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
data_index = 0

# generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    # make sure our parameters are self-consistent
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    # create empty batch ndarray using 'batch_size'
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    # create empty labels ndarray using 'batch_size'
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    # [ skip_window target skip_window ]
    span = 2 * skip_window + 1
    # create a buffer object for prepping batch data
    buffer = collections.deque(maxlen=span)
    # for each element in our calculated span, append the datum at 'data_index' and increment 'data_index' moduli the amount of data
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    # loop for 'batch_size' // 'num_skips'
    for i in range(batch_size // num_skips):
         # target label at the center of the buffer
        target = skip_window
        targets_to_avoid = [skip_window]
        # loop for 'num_skips'
        for j in range(num_skips):
            # loop through all 'targets_to_avoid'
            while target in targets_to_avoid:
                # pick a random index as target
                target = random.randint(0, span - 1)
            # put it in 'targets_to_avoid'
            targets_to_avoid.append(target)
            # set the skip window in the minibatch data
            batch[i * num_skips + j] = buffer[skip_window]
            # set the target in the minibatch labels
            labels[i * num_skips + j, 0] = buffer[target]
        # add the data at the current 'data_index' to the buffer
        buffer.append(data[data_index])
        # increment 'data_index'
        data_index = (data_index + 1) % len(data)
    # return the minibatch data and corresponding labels
    return batch, labels

# get a minibatch
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)

# print out part of the minibatch to the console
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3083 originated -> 5242 anarchism
# 3083 originated -> 12 as
# 12 as -> 6 a
# 12 as -> 3083 originated
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 2 of
# 195 term -> 6 a

# %%
# hyperparameters
batch_size = 128
embedding_size = 128 # dimension of the embedding vector
skip_window = 1 # how many words to consider to left and right
num_skips = 2 # how many times to reuse an input to generate a label

# we choose random validation dataset to sample nearest neighbors
# here, we limit the validation samples to the words that have a low
# numeric ID, which are also the most frequently occurring words
valid_size = 16 # size of random set of words to evaluate similarity on
valid_window = 100 # only pick development samples from the first 'valid_window' words
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64 # number of negative examples to sample

# create computation graph
graph = tf.Graph()

with graph.as_default():
    # input data
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # operations and variables
    # look up embeddings for inputs
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # construct the variables for the NCE loss
    nce_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each time we evaluate the loss.
    loss = tf.reduce_mean(tf.nn.nce_loss(weights=nce_weights, biases=nce_biases,
                     labels=train_labels, inputs=embed, num_sampled=num_sampled, num_classes=vocabulary_size))
    
    # construct the SGD optimizer using a learning rate of 1.0
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # compute the cosine similarity between minibatch examples and all embeddings
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, normalized_embeddings, transpose_b=True)

    # add variable initializer
    init = tf.initialize_all_variables()
# Out:
# WARNING:tensorflow:From <ipython-input-6-20fc4bcb7bce>:48: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.

# %%
# steps to train the model
num_steps = 100001
steplist=[]
losslist=[]

with tf.Session(graph=graph) as session:
    # we must initialize all variables before using them
    init.run()
    print('initialized.')
    
    # loop through all training steps and keep track of loss
    average_loss = 0
    for step in xrange(num_steps):
        # generate a minibatch of training data
        batch_inputs, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}
        
        # we perform a single update step by evaluating the optimizer operation (including it
        # in the list of returned values of session.run())
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val
        
        # print average loss every 2,000 steps
        if step % 2000 == 0:
            steplist.append(step)
            if step > 0:
                average_loss /= 2000
            # the average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            losslist.append(average_loss)
            average_loss = 0
        
        # computing cosine similarity (expensive!)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                # get a single validation sample
                valid_word = reverse_dictionary[valid_examples[i]]
                # number of nearest neighbors
                top_k = 8
                # computing nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = "nearest to %s:" % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
        
    final_embeddings = normalized_embeddings.eval()
# Out:
# initialized.
# Average loss at step  0 :  273.704223633
# nearest to to: howie, cream, organum, rhee, hertford, subset, bookstores, morgenstern,
# nearest to more: unpopularity, spark, cracked, mmc, estuary, lucrezia, bedrooms, dependency,
# nearest to known: congregation, fatherland, bubbled, conquering, wouldn, cirencester, hindemith, gana,
# nearest to there: dip, alcoholics, peltier, cheques, medici, condenses, assemble, leah,
# nearest to such: pragmatic, indebtedness, consulting, slept, unspecified, suddenly, dung, dir,
# nearest to people: behaviorism, arr, taxes, inconspicuous, centerline, renegades, zanetti, substrates,
# nearest to which: mcp, higher, assessments, ramone, pda, ka, guelleh, unpopularity,
# nearest to see: paper, proposes, devout, disused, evasive, ballista, pam, leper,
# nearest to may: had, homegrown, divisive, ertegun, cements, fenced, lights, apec,
# nearest to will: waved, hiram, minded, sharpe, glosses, them, persepolis, deposition,
# nearest to when: toc, strident, invite, kalmyks, macduff, dna, semiotic, reigned,
# nearest to be: laws, wishful, decimals, shut, man, boiling, eats, occur,
# nearest to th: dysprosium, weld, labeling, bouncer, draconian, shearer, gatt, ditch,
# nearest to about: plumes, approximately, brahmins, choices, afer, drummond, tha, stencils,
# nearest to six: monomorphism, ductile, creole, mouvement, amd, damnation, lapses, myrddin,
# nearest to is: abbess, flow, geometrical, errors, qoheleth, icsu, accelerated, handle,
# Average loss at step  2000 :  113.866194041
# Average loss at step  4000 :  53.1011063855
# Average loss at step  6000 :  33.4110873537
# Average loss at step  8000 :  23.1309355167
# Average loss at step  10000 :  18.0901937857
# nearest to to: and, in, analogue, not, rudolph, alpina, executive, of,
# nearest to more: spark, reginae, ever, agave, yard, acts, magazine, region,
# nearest to known: congregation, vs, mac, riding, completed, pump, backyard, conquering,
# nearest to there: gay, thereof, some, material, erected, alpina, eugenicists, miserable,
# nearest to such: amo, manufactured, suddenly, segmental, reginae, belongs, slept, chief,
# nearest to people: taxes, integrated, compatibility, efficient, homomorphism, reginae, seized, determined,
# nearest to which: higher, algae, and, align, reginae, hasten, cartridge, ka,
# nearest to see: paper, executed, proposes, quantum, analogue, enlisted, feature, croatia,
# nearest to may: had, syriac, phrase, conducted, fide, ireland, victoriae, cc,
# nearest to will: them, house, to, minded, reginae, african, dominion, party,
# nearest to when: toc, cognition, carry, discussion, body, seven, equality, altenberg,
# nearest to be: occur, metropolitan, was, shut, asiatic, man, plan, pets,
# nearest to th: vs, agent, eight, advances, reginae, zero, gb, one,
# nearest to about: approximately, vs, choices, fins, painter, disorder, afer, mirrors,
# nearest to six: nine, zero, analogue, five, vs, victoriae, pottery, seven,
# nearest to is: was, are, vs, would, agave, victoriae, irrational, as,
# Average loss at step  12000 :  14.1107081416
# Average loss at step  14000 :  11.6702839556
# Average loss at step  16000 :  9.87649518836
# Average loss at step  18000 :  8.59597225451
# Average loss at step  20000 :  7.77750288427
# nearest to to: and, in, not, nine, for, lawgiver, on, dasyprocta,
# nearest to more: spark, ever, unpopularity, which, UNK, agouti, poitiers, books,
# nearest to known: congregation, pump, mac, fatherland, identifying, vs, interval, riding,
# nearest to there: it, some, medici, thereof, lawgiver, gay, eugenicists, not,
# nearest to such: amo, manufactured, chief, belongs, roused, gamma, segmental, dasyprocta,
# nearest to people: taxes, integrated, mango, compatibility, dasyprocta, ff, reginae, homomorphism,
# nearest to which: it, and, summary, that, cartridge, this, reginae, hasten,
# nearest to see: agassiz, executed, paper, proposes, croatia, quantum, banished, claudius,
# nearest to may: had, divisive, syriac, absalom, agouti, conducted, four, nine,
# nearest to will: waved, to, minded, them, dominion, antares, annales, airways,
# nearest to when: and, reigned, contradictory, seven, is, equality, carry, nine,
# nearest to be: was, have, is, metropolitan, occur, touching, pets, refer,
# nearest to th: eight, zero, epistles, seven, five, advances, dasyprocta, agent,
# nearest to about: approximately, seven, vs, choices, sancti, fins, four, afer,
# nearest to six: nine, five, zero, four, three, eight, seven, dasyprocta,
# nearest to is: was, are, were, as, by, victoriae, nine, has,
# Average loss at step  22000 :  7.21896447754
# Average loss at step  24000 :  6.86224147367
# Average loss at step  26000 :  6.64511787975
# Average loss at step  28000 :  6.16193806839
# Average loss at step  30000 :  6.23995747292
# nearest to to: for, not, nine, and, in, analogue, ark, would,
# nearest to more: spark, ever, hardback, less, unpopularity, poitiers, scots, books,
# nearest to known: congregation, pump, identifying, a, vdash, interval, mac, continuing,
# nearest to there: it, some, not, lawgiver, medici, which, thereof, eugenicists,
# nearest to such: amo, manufactured, chief, roused, gamma, belongs, long, segmental,
# nearest to people: taxes, substrates, compatibility, mango, integrated, ff, reginae, helmut,
# nearest to which: it, that, this, and, subsonic, summary, also, mcp,
# nearest to see: agassiz, proposes, executed, paper, and, feature, nbs, croatia,
# nearest to may: would, had, four, could, syriac, nine, divisive, can,
# nearest to will: waved, can, to, minded, them, dominion, would, annales,
# nearest to when: and, is, seven, contradictory, but, was, if, cyclase,
# nearest to be: was, have, is, by, been, refer, occur, metropolitan,
# nearest to th: eight, seven, five, uhf, nine, four, epistles, zero,
# nearest to about: approximately, seven, choices, sancti, ancestral, vs, antibodies, from,
# nearest to six: five, nine, eight, four, seven, three, zero, two,
# nearest to is: was, are, were, as, has, victoriae, became, chattel,
# Average loss at step  32000 :  5.81956486571
# Average loss at step  34000 :  5.87022568226
# Average loss at step  36000 :  5.65691021872
# Average loss at step  38000 :  5.25251554608
# Average loss at step  40000 :  5.49463857961
# nearest to to: will, for, nine, analogue, gimme, not, cubs, must,
# nearest to more: less, very, spark, ever, books, hardback, afl, ifor,
# nearest to known: congregation, pump, identifying, conquering, continuing, mac, computes, vdash,
# nearest to there: it, which, not, he, some, lawgiver, and, eugenicists,
# nearest to such: manufactured, well, amo, chief, gamma, dasyprocta, roused, long,
# nearest to people: taxes, substrates, mango, compatibility, integrated, helmut, reginae, annales,
# nearest to which: that, it, this, and, also, subsonic, but, one,
# nearest to see: agassiz, proposes, executed, tanenbaum, paper, and, feature, nbs,
# nearest to may: would, can, could, four, should, skirts, absalom, will,
# nearest to will: can, to, would, waved, minded, could, may, them,
# nearest to when: and, but, is, seven, if, contradictory, where, was,
# nearest to be: have, was, is, by, been, were, refer, make,
# nearest to th: eight, seven, zero, five, uhf, six, epistles, nine,
# nearest to about: approximately, choices, four, drummond, from, lemmy, sabra, seven,
# nearest to six: five, eight, four, seven, three, nine, zero, two,
# nearest to is: was, are, were, has, became, victoriae, as, schenectady,
# Average loss at step  42000 :  5.32984516835
# Average loss at step  44000 :  5.33034779072
# Average loss at step  46000 :  5.27832262778
# Average loss at step  48000 :  5.02852818239
# Average loss at step  50000 :  5.17167321849
# nearest to to: will, analogue, for, can, would, nine, must, not,
# nearest to more: less, very, spark, renarrative, screwed, ever, ifor, books,
# nearest to known: congregation, pump, identifying, continuing, conquering, well, mac, interval,
# nearest to there: it, which, he, not, some, they, eugenicists, still,
# nearest to such: well, manufactured, chief, gamma, known, amo, long, sandbox,
# nearest to people: substrates, mango, integrated, taxes, compatibility, helmut, reginae, exception,
# nearest to which: this, that, it, also, and, but, there, subsonic,
# nearest to see: proposes, agassiz, executed, tanenbaum, stanza, feature, ghost, evasive,
# nearest to may: can, would, could, should, will, skirts, absalom, agouti,
# nearest to will: can, would, could, to, may, hiram, waved, must,
# nearest to when: seven, but, and, where, eight, if, is, during,
# nearest to be: have, was, been, by, is, were, refer, make,
# nearest to th: five, seven, eight, zero, uhf, nine, four, three,
# nearest to about: approximately, choices, drummond, seven, four, lemmy, sabra, navin,
# nearest to six: eight, four, five, seven, three, nine, two, zero,
# nearest to is: was, are, has, were, victoriae, as, be, became,
# Average loss at step  52000 :  5.19281691194
# Average loss at step  54000 :  5.10325230265
# Average loss at step  56000 :  5.07493244874
# Average loss at step  58000 :  5.1515312649
# Average loss at step  60000 :  4.94857410318
# nearest to to: would, can, will, not, nine, must, analogue, cubs,
# nearest to more: less, very, saguinus, spark, renarrative, screwed, ifor, inmarsat,
# nearest to known: congregation, bubbled, well, such, pump, used, conquering, continuing,
# nearest to there: it, which, they, he, still, this, not, eugenicists,
# nearest to such: well, manufactured, known, chief, gamma, saguinus, sandbox, dasyprocta,
# nearest to people: substrates, compatibility, mango, taxes, saguinus, integrated, helmut, toxin,
# nearest to which: that, this, it, callithrix, but, also, there, thibetanus,
# nearest to see: but, agassiz, proposes, tanenbaum, stanza, ghost, nbs, feature,
# nearest to may: can, would, could, will, should, might, to, opteron,
# nearest to will: can, would, could, may, cebus, to, hiram, must,
# nearest to when: but, where, and, if, tamarin, seven, during, is,
# nearest to be: been, was, have, by, refer, were, is, are,
# nearest to th: eight, five, nine, six, zero, four, seven, uhf,
# nearest to about: approximately, choices, seven, over, navin, drummond, sabra, lemmy,
# nearest to six: eight, five, seven, four, nine, three, zero, tamarin,
# nearest to is: was, are, has, tamarin, victoriae, microcebus, became, bebox,
# Average loss at step  62000 :  4.78591727722
# Average loss at step  64000 :  4.7932230866
# Average loss at step  66000 :  4.96126298404
# Average loss at step  68000 :  4.9205973202
# Average loss at step  70000 :  4.77948904443
# nearest to to: would, can, will, must, for, not, analogue, nine,
# nearest to more: less, very, saguinus, inmarsat, spark, screwed, renarrative, ifor,
# nearest to known: congregation, used, such, well, bubbled, conquering, succeed, seen,
# nearest to there: it, they, which, still, this, he, often, eugenicists,
# nearest to such: well, known, manufactured, many, other, some, chromic, these,
# nearest to people: substrates, compatibility, mango, integrated, goo, cassettes, volante, mugwort,
# nearest to which: that, this, but, also, callithrix, it, and, there,
# nearest to see: but, stanza, proposes, tanenbaum, adjectival, ghost, agassiz, five,
# nearest to may: can, would, could, will, should, might, cannot, to,
# nearest to will: can, would, may, could, cebus, must, to, hiram,
# nearest to when: but, where, if, during, and, is, tamarin, before,
# nearest to be: been, were, have, by, was, is, refer, are,
# nearest to th: eight, seven, six, zero, nine, five, uhf, four,
# nearest to about: approximately, over, choices, sabra, navin, drummond, callithrix, seven,
# nearest to six: eight, four, five, seven, three, nine, zero, two,
# nearest to is: was, are, has, became, tamarin, microcebus, victoriae, when,
# Average loss at step  72000 :  4.80038988483
# Average loss at step  74000 :  4.77998777074
# Average loss at step  76000 :  4.8539179374
# Average loss at step  78000 :  4.78288056672
# Average loss at step  80000 :  4.82143967986
# nearest to to: must, will, would, nine, can, cubs, pontificia, analogue,
# nearest to more: less, very, saguinus, screwed, inmarsat, most, spark, ammanati,
# nearest to known: used, congregation, such, well, bubbled, seen, succeed, conquering,
# nearest to there: it, they, which, still, he, often, this, usually,
# nearest to such: well, many, these, known, manufactured, some, including, sandbox,
# nearest to people: substrates, compatibility, mango, goo, cassettes, ishmael, volante, integrated,
# nearest to which: this, that, also, it, but, callithrix, there, trapezohedron,
# nearest to see: but, stanza, proposes, adjectival, tanenbaum, ghost, evasive, nbs,
# nearest to may: can, would, could, will, should, might, must, cannot,
# nearest to will: can, would, may, could, cebus, must, should, to,
# nearest to when: but, where, if, during, and, before, while, tamarin,
# nearest to be: been, was, were, have, by, being, is, refer,
# nearest to th: eight, nine, five, four, six, seven, zero, uhf,
# nearest to about: over, approximately, seven, choices, callithrix, sabra, rulings, navin,
# nearest to six: five, four, seven, eight, three, nine, two, zero,
# nearest to is: was, has, are, became, tamarin, be, victoriae, microcebus,
# Average loss at step  82000 :  4.80187293577
# Average loss at step  84000 :  4.79883439171
# Average loss at step  86000 :  4.75751843715
# Average loss at step  88000 :  4.67978105092
# Average loss at step  90000 :  4.75250380039
# nearest to to: would, pontificia, will, must, nine, can, analogue, cebus,
# nearest to more: less, very, most, saguinus, inmarsat, screwed, spark, ifor,
# nearest to known: used, congregation, such, well, seen, stickball, bubbled, conquering,
# nearest to there: it, they, which, he, still, often, usually, this,
# nearest to such: well, known, these, many, manufactured, including, some, wiesbaden,
# nearest to people: compatibility, ishmael, cassettes, substrates, mango, goo, mugwort, volante,
# nearest to which: that, this, but, also, it, callithrix, there, trapezohedron,
# nearest to see: but, stanza, adjectival, ghost, proposes, tanenbaum, snowman, evasive,
# nearest to may: can, would, could, will, should, might, must, cannot,
# nearest to will: can, would, may, could, must, should, might, cebus,
# nearest to when: if, where, during, while, but, before, although, seven,
# nearest to be: been, have, was, were, refer, are, is, being,
# nearest to th: seven, eight, nine, six, five, four, zero, uhf,
# nearest to about: over, approximately, sabra, choices, navin, rulings, invariants, callithrix,
# nearest to six: five, eight, seven, four, three, nine, two, zero,
# nearest to is: was, has, are, became, tamarin, victoriae, be, microcebus,
# Average loss at step  92000 :  4.70819432092
# Average loss at step  94000 :  4.61964754498
# Average loss at step  96000 :  4.7217277751
# Average loss at step  98000 :  4.63572528481
# Average loss at step  100000 :  4.66389884615
# nearest to to: will, can, would, must, pontificia, analogue, cubs, nine,
# nearest to more: less, very, most, saguinus, screwed, inmarsat, spark, ammanati,
# nearest to known: used, such, congregation, well, seen, stickball, succeed, vdash,
# nearest to there: it, they, he, still, often, which, usually, this,
# nearest to such: well, these, known, many, including, manufactured, some, wiesbaden,
# nearest to people: ishmael, goo, mugwort, cassettes, saguinus, mango, compatibility, volante,
# nearest to which: that, this, but, it, also, callithrix, these, trapezohedron,
# nearest to see: but, stanza, adjectival, snowman, tanenbaum, and, list, ghost,
# nearest to may: can, would, will, could, should, might, must, cannot,
# nearest to will: would, can, may, could, must, should, might, to,
# nearest to when: if, where, while, during, before, although, but, and,
# nearest to be: been, have, refer, was, are, were, by, being,
# nearest to th: nine, seven, eight, five, six, uhf, zero, four,
# nearest to about: over, approximately, sabra, choices, navin, callithrix, rulings, invariants,
# nearest to six: seven, five, four, eight, three, nine, two, zero,
# nearest to is: was, has, are, became, tamarin, victoriae, microcebus, were,

# %%
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    # set plot size in inches
    plt.figure(figsize=(18, 18))
    # loop through all labels
    for i, label in enumerate(labels):
        # get the embedding vectors
        x, y = low_dim_embs[i, :]
        # plot them in a scatterplot
        plt.scatter(x, y)
        # annotations
        plt.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')

    # save the figure out
    plt.savefig(filename)

try:
    # import t-SNE and matplotlib.pyplot
    from sklearn.manifold import TSNE
    import matplotlib.pyplot as plt
    
    # %matplotlib inline

    # create the t-SNE object with 2 components, PCA initialization, and 5000 iterations
    tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
    # plot only so many words in the embedding
    plot_only = 500
    # fit the TSNE dimensionality reduction technique to the word vector embedding
    low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
    # get the words associated with the points
    labels = [reverse_dictionary[i] for i in xrange(plot_only)]
    # call the plotting function
    plot_with_labels(low_dim_embs, labels)

except ImportError:
    print("Please install sklearn, matplotlib, and scipy to visualize embeddings.")

# %%
    for i in xrange(valid_size):
                # get a single validation sample
                valid_word = reverse_dictionary[valid_examples[i]]
                # number of nearest neighbors
                top_k = 8
                # computing nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = "nearest to %s:" % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
# Out:
# nearest to to: will, can, would, must, pontificia, analogue, cubs, nine,
# nearest to more: less, very, most, saguinus, screwed, inmarsat, spark, ammanati,
# nearest to known: used, such, congregation, well, seen, stickball, succeed, vdash,
# nearest to there: it, they, he, still, often, which, usually, this,
# nearest to such: well, these, known, many, including, manufactured, some, wiesbaden,
# nearest to people: ishmael, goo, mugwort, cassettes, saguinus, mango, compatibility, volante,
# nearest to which: that, this, but, it, also, callithrix, these, trapezohedron,
# nearest to see: but, stanza, adjectival, snowman, tanenbaum, and, list, ghost,
# nearest to may: can, would, will, could, should, might, must, cannot,
# nearest to will: would, can, may, could, must, should, might, to,
# nearest to when: if, where, while, during, before, although, but, and,
# nearest to be: been, have, refer, was, are, were, by, being,
# nearest to th: nine, seven, eight, five, six, uhf, zero, four,
# nearest to about: over, approximately, sabra, choices, navin, callithrix, rulings, invariants,
# nearest to six: seven, five, four, eight, three, nine, two, zero,
# nearest to is: was, has, are, became, tamarin, victoriae, microcebus, were,
